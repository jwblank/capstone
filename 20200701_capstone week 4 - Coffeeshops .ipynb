# %% [markdown]
# <h1> DataScience Capstone Project: </h1>
#
# <h2>The Battle of the Neighborhoods </h2>
#
# <p> An analysis of various neighborhoods in different cities in Amsterdam. This Notebook consists of two parts. The first part defines the problem statement and the potential solution for that problem statement.
# The second part of the notebook describes the actual solution for the problem statement.
#
# Section 1 - introduction / Problem statement
# An investor wants to open a coffee-shop in Amsterdam. I will make an analysis for the best location.
#
# The best location in this case is related to other venues in the vincinity that attract customers. This could be restaurants, parks, university faculties, companies. But also the lack of other coffee-venues in the area.
#
# Data selection and requirements
# To answer the questions, I want to source data from Foursquare. To do the analysis I will use Jupyter notebooks. I'm going to use include map-visualization, analytical libraries and libraries that make it convenient to work with datasets.
#
# To answer my question, I want to create a lists of different types of venues. Once I have categorized and clustered them, I want to plot them on a map. Based on this, I want to be able to show the best area for the coffee-shop to be opened.<p>

# %%
# first ensure that potentially required libraries are loaded
import pandas as pd
import numpy as np
import json

#from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.pylab as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !pip install folium
# !pip install geopy 

import folium # map rendering library
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
print('Libraries imported.')
# Out:
# Requirement already satisfied: folium in /Users/info/anaconda3/lib/python3.7/site-packages (0.11.0)
# Requirement already satisfied: numpy in /Users/info/anaconda3/lib/python3.7/site-packages (from folium) (1.16.2)
# Requirement already satisfied: branca>=0.3.0 in /Users/info/anaconda3/lib/python3.7/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/info/anaconda3/lib/python3.7/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /Users/info/anaconda3/lib/python3.7/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/info/anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/info/anaconda3/lib/python3.7/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/info/anaconda3/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/info/anaconda3/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/info/anaconda3/lib/python3.7/site-packages (from requests->folium) (2019.3.9)
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/07/e1/9c72de674d5c2b8fcb0738a5ceeb5424941fefa080bfe4e240d0bacb5a38/geopy-2.0.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 2.6MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.0.0
# Libraries imported.

# %%
# Foursquare credentials
CLIENT_ID = 'EZQVPDQ0DFYGXIEFRYUTYT0VAN3JMZRPGXC55YUTYBFM4Z5V' # your Foursquare ID
CLIENT_SECRET = '4LTHONG5R4ZM0X1IQQBHH03IQFHKAV0LBZDAY4RSNT5OAJLC' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EZQVPDQ0DFYGXIEFRYUTYT0VAN3JMZRPGXC55YUTYBFM4Z5V
# CLIENT_SECRET:4LTHONG5R4ZM0X1IQQBHH03IQFHKAV0LBZDAY4RSNT5OAJLC

# %%
# Find the coordinates of the center of Amsterdam (called "De Dam")

address = 'Dam, Amsterdam, Netherlands'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 52.37324375 4.892515060740985

# %%
# first we search fr coffeeshops
search_query = "Coffee"
radius = 500
print(search_query + 'I found it')
# Out:
# CoffeeI found it

# %%
coffee_url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
#coffee_url
coffee_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EZQVPDQ0DFYGXIEFRYUTYT0VAN3JMZRPGXC55YUTYBFM4Z5V&client_secret=4LTHONG5R4ZM0X1IQQBHH03IQFHKAV0LBZDAY4RSNT5OAJLC&ll=52.37324375,4.892515060740985&v=20180605&query=Coffee&radius=500&limit=100'

# %%
coffee_results = requests.get(coffee_url).json()
#coffee_results

# assign relevant information to venues
venues = coffee_results['response']['venues']
# transform venues to a dataframe
dfv = json_normalize(venues)
dfv.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
#
#                          id             location.address location.cc  \
# 0  5257fe4b11d27692834290b9                     Rokin 55          NL
# 1  4e2010e418a88345f03c3d3b  Nieuwezijds Voorburgwal 132          NL
# 2  4a2705cff964a520f5881fe3                      Spui 28          NL
# 3  5c681cc41acf11002c7aa0d7                          NaN          NL
# 4  5bdec64f8fb09e002cbbf24f                       Dam 10          NL
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     Amsterdam        Nederland                  NaN                152
# 1     Amsterdam        Nederland                  NaN                204
# 2     Amsterdam        Nederland           Spuistraat                553
# 3     Amsterdam        Nederland                  NaN                523
# 4     Amsterdam        Nederland                  NaN                 42
#
#                            location.formattedAddress  \
# 0                   [Rokin 55, Amsterdam, Nederland]
# 1  [Nieuwezijds Voorburgwal 132, 1012 SH Amsterda...
# 2  [Spui 28 (Spuistraat), 1012 XA Amsterdam, Nede...
# 3                     [1012 XA Amsterdam, Nederland]
# 4             [Dam 10, 1012 NP Amsterdam, Nederland]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 52.37204859355692...     52.372049
# 1  [{'label': 'display', 'lat': 52.3750366665651,...     52.375037
# 2  [{'label': 'display', 'lat': 52.36869570531105...     52.368696
# 3  [{'label': 'display', 'lat': 52.36891, 'lng': ...     52.368910
# 4  [{'label': 'display', 'lat': 52.373604, 'lng':...     52.373604
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0      4.893601                   NaN                 NaN  Noord-Holland
# 1      4.891881                   NaN             1012 SH  Noord-Holland
# 2      4.889210                   NaN             1012 XA  Noord-Holland
# 3      4.889540     Stadsdeel Centrum             1012 XA  Noord-Holland
# 4      4.892299     Stadsdeel Centrum             1012 NP  Noord-Holland
#
#                                     name    referralId venuePage.id
# 0                    Lois Coffee & Jeans  v-1593601066          NaN
# 1  Hostel Utopia/Coffee Shop (Amsterdam)  v-1593601066          NaN
# 2                         Coffee Company  v-1593601066          NaN
# 3                         Harar Coffee 2  v-1593601066          NaN
# 4                           Naked Coffee  v-1593601066          NaN

# %%
# Now for some data-wrangling. Drop the columns I don't need. 
filtered_columns = ['name', 'categories'] + [col for col in dfv.columns if col.startswith('location.')] +  ['id']
dfv_filtered = dfv.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfv_filtered['categories'] = dfv_filtered.apply(get_category_type, axis=1)
# clean column names by keeping only last term
dfv_filtered.columns = [column.split('.')[-1] for column in dfv_filtered.columns]

dfv_filtered
# Out:
#                                         name            categories  \
# 0                        Lois Coffee & Jeans        Clothing Store
# 1      Hostel Utopia/Coffee Shop (Amsterdam)             Hotel Bar
# 2                             Coffee Company           Coffee Shop
# 3                             Harar Coffee 2           Coffee Shop
# 4                               Naked Coffee           Coffee Shop
# 5                              Coffeecompany           Coffee Shop
# 6                         Coffee Club Damrak           Coffee Shop
# 7                            Coffeeshop Solo  Marijuana Dispensary
# 8                             Coffee & Cakes                  Café
# 9                           Coffee bread bar           Coffee Shop
# 10  Coffee Shop Cafe Utrecht Utrech Panorama                  Café
# 11                      Blowerij Coffee Shop           Coffee Shop
# 12                      lexi’s Coffee&Bakery           Coffee Shop
# 13             Lot Sixty One Coffee Roasters           Coffee Shop
# 14                        Coffeeshop Rusland  Marijuana Dispensary
# 15                          Canal Coffee Co.           Coffee Shop
# 16                        Sativa Coffee Shop           Coffee Shop
# 17                   original primium coffee                Bakery
# 18                        Coffee@last Damrak           Coffee Shop
# 19                Coffee Company Kalvertoren           Coffee Shop
# 20                             Coffee @ last           Coffee Shop
# 21                   Pancakes Tosti's Coffee                  Café
# 22                          Louis Bed&Coffee       Bed & Breakfast
# 23                          Louis Bed&Coffee       Bed & Breakfast
# 24                      Cannabis Coffee Shop           Coffee Shop
# 25                       Highway Coffeeshoop                  Café
# 26                              Urban coffee                  Café
# 27                    Old Church Coffee Shop  Marijuana Dispensary
# 28         Green Place Coffee Shop Amsterdam                   Pub
# 29                       Hunter's Coffeeshop  Marijuana Dispensary
# 30                    Dutchies Coffee & Shop           Coffee Shop
# 31                           District Coffee                  Café
# 32             Lot Sixty One Coffee Roasters           Coffee Shop
# 33           Miss Louisa Coffee And Beignets           Coffee Shop
# 34                              Bocca Coffee                  Café
# 35                              Tasty Coffee           Coffee Shop
# 36          prix d'amis coffeeshop amsterdam  Marijuana Dispensary
# 37                     Tasty Donuts & Coffee            Donut Shop
# 38                       De Koffieschenkerij           Coffee Shop
# 39                                Cut Throat    Salon / Barbershop
# 40                                coffeechop            Hookah Bar
# 41                                   coffeez                  Café
# 42                             CoffeeCompany           Coffee Shop
# 43                    Coffeeshop Mediteranne           Coffee Shop
# 44                 Coffeeshop weed deliveren  Marijuana Dispensary
# 45                                 Greendayz           Coffee Shop
# 46                      Coffeeshop City Hall           Coffee Shop
# 47                        Coffeeshop Babylon  Marijuana Dispensary
# 48                   Coffeeshop The Basement            Smoke Shop
# 49                         Coffeeshop Extase            Smoke Shop
#
#                             address  cc       city    country  \
# 0                          Rokin 55  NL  Amsterdam  Nederland
# 1       Nieuwezijds Voorburgwal 132  NL  Amsterdam  Nederland
# 2                           Spui 28  NL  Amsterdam  Nederland
# 3                               NaN  NL  Amsterdam  Nederland
# 4                            Dam 10  NL  Amsterdam  Nederland
# 5              Oude Doelenstraat 11  NL  Amsterdam  Nederland
# 6                  Beurspassage 12A  NL  Amsterdam  Nederland
# 7             Korte Koningsstraat 2  NL  Amsterdam  Nederland
# 8                               NaN  NL        NaN  Nederland
# 9                             Rokin  NL  Amsterdam  Nederland
# 10                              NaN  NL        NaN  Nederland
# 11                              NaN  NL  Amsterdam  Nederland
# 12                         Rokin 65  NL  Amsterdam  Nederland
# 13                  Kalverstraat 31  NL  Amsterdam  Nederland
# 14                       Rusland 16  NL  Amsterdam  Nederland
# 15                              NaN  NL        NaN  Nederland
# 16                              NaN  NL  Amsterdam  Nederland
# 17                              NaN  NL        NaN  Nederland
# 18                        Damrak 11  NL  Amsterdam  Nederland
# 19                           Singel  NL  Amsterdam  Nederland
# 20                        Damrak 11  NL  Amsterdam  Nederland
# 21                              NaN  NL        NaN  Nederland
# 22                              NaN  NL        NaN  Nederland
# 23                              NaN  NL        NaN  Nederland
# 24     Haarlemmerstraat 44, 1013 ES  NL  Amsterdam  Nederland
# 25                              NaN  NL  Amsterdam  Nederland
# 26                              NaN  NL        NaN  Nederland
# 27                         Amstel 8  NL  Amsterdam  Nederland
# 28                              NaN  NL        NaN  Nederland
# 29                 Warmoesstraat 24  NL  Amsterdam  Nederland
# 30       Oudezijds Achterburgwal 63  NL  Amsterdam  Nederland
# 31                              NaN  NL  Amsterdam  Nederland
# 32                              NaN  NL  Amsterdam  Nederland
# 33        Nieuwezijds Voorburgwal 5  NL  Amsterdam  Nederland
# 34                              NaN  NL  Amsterdam  Nederland
# 35                              NaN  NL  Amsterdam  Nederland
# 36                              NaN  NL        NaN  Nederland
# 37          Reguliersbreestraat 19H  NL  Amsterdam  Nederland
# 38                Oudekerksplein 27  NL  Amsterdam  Nederland
# 39                     Beursplein 5  NL  Amsterdam  Nederland
# 40                              NaN  NL  Amsterdam  Nederland
# 41                     Beurspassage  NL  Amsterdam  Nederland
# 42                        Damstraat  NL  Amsterdam  Nederland
# 43                    Spuistraat 80  NL  Amsterdam  Nederland
# 44  Eerste van der Helststraat 70HS  NL  Amsterdam  Nederland
# 45                 Warmoestraat 143  NL  Amsterdam  Nederland
# 46                              NaN  NL        NaN  Nederland
# 47                      Beursstraat  NL  Amsterdam  Nederland
# 48                              NaN  NL        NaN  Nederland
# 49                Oude Hoogstraat 2  NL  Amsterdam  Nederland
#
#                 crossStreet  distance  \
# 0                       NaN       152
# 1                       NaN       204
# 2                Spuistraat       553
# 3                       NaN       523
# 4                       NaN        42
# 5                       NaN       340
# 6                       NaN        48
# 7                       NaN       211
# 8                       NaN       297
# 9        Wijde Lombardsteeg       262
# 10                      NaN       234
# 11                      NaN       113
# 12                      NaN       250
# 13                      NaN       188
# 14                      NaN       434
# 15                      NaN       221
# 16                      NaN       211
# 17                      NaN       218
# 18                      NaN       526
# 19                      NaN       640
# 20                      NaN       527
# 21                      NaN       314
# 22                      NaN       358
# 23                      NaN       391
# 24                Hekelveld       391
# 25                      NaN       478
# 26                      NaN       402
# 27                      NaN       357
# 28                      NaN       410
# 29                      NaN       519
# 30                      NaN       435
# 31                      NaN       441
# 32                      NaN       484
# 33                      NaN       520
# 34               kerkstraat       496
# 35                      NaN       599
# 36                      NaN        22
# 37                      NaN       731
# 38    Oudezijds Voorburgwal       411
# 39                      NaN       252
# 40                      NaN       126
# 41                      NaN       199
# 42                      NaN       219
# 43                      NaN       265
# 44            warmoesstraat       300
# 45                      NaN       221
# 46                      NaN       262
# 47                      NaN       276
# 48                      NaN       347
# 49  Oudezijds Achterburgwal       351
#
#                                      formattedAddress  \
# 0                    [Rokin 55, Amsterdam, Nederland]
# 1   [Nieuwezijds Voorburgwal 132, 1012 SH Amsterda...
# 2   [Spui 28 (Spuistraat), 1012 XA Amsterdam, Nede...
# 3                      [1012 XA Amsterdam, Nederland]
# 4              [Dam 10, 1012 NP Amsterdam, Nederland]
# 5   [Oude Doelenstraat 11, 1012 ED Amsterdam, Nede...
# 6    [Beurspassage 12A, 1012 LW Amsterdam, Nederland]
# 7   [Korte Koningsstraat 2, 1011 GA Amsterdam, Ned...
# 8                                         [Nederland]
# 9   [Rokin (Wijde Lombardsteeg), 1012 KL Amsterdam...
# 10                                        [Nederland]
# 11                             [Amsterdam, Nederland]
# 12           [Rokin 65, 1012 KK Amsterdam, Nederland]
# 13    [Kalverstraat 31, 1012 NX Amsterdam, Nederland]
# 14         [Rusland 16, 1012 CL Amsterdam, Nederland]
# 15                                        [Nederland]
# 16                     [1012 VA Amsterdam, Nederland]
# 17                                        [Nederland]
# 18                  [Damrak 11, Amsterdam, Nederland]
# 19                     [Singel, Amsterdam, Nederland]
# 20                  [Damrak 11, Amsterdam, Nederland]
# 21                                        [Nederland]
# 22                                        [Nederland]
# 23                                        [Nederland]
# 24  [Haarlemmerstraat 44, 1013 ES (Hekelveld), Ams...
# 25                             [Amsterdam, Nederland]
# 26                                        [Nederland]
# 27           [Amstel 8, 1012 HA Amsterdam, Nederland]
# 28                                        [Nederland]
# 29   [Warmoesstraat 24, 1012 JD Amsterdam, Nederland]
# 30  [Oudezijds Achterburgwal 63, 1012 DB Amsterdam...
# 31                     [1012 DR Amsterdam, Nederland]
# 32                     [1012 RC Amsterdam, Nederland]
# 33  [Nieuwezijds Voorburgwal 5, 1012RC Amsterdam, ...
# 34                 [kerkstraat, Amsterdam, Nederland]
# 35                     [1012 VC Amsterdam, Nederland]
# 36                                        [Nederland]
# 37    [Reguliersbreestraat 19H, Amsterdam, Nederland]
# 38  [Oudekerksplein 27 (Oudezijds Voorburgwal), 10...
# 39       [Beursplein 5, 1012 JV Amsterdam, Nederland]
# 40                             [Amsterdam, Nederland]
# 41               [Beurspassage, Amsterdam, Nederland]
# 42                  [Damstraat, Amsterdam, Nederland]
# 43      [Spuistraat 80, 1012 ST Amsterdam, Nederland]
# 44  [Eerste van der Helststraat 70HS (warmoesstraa...
# 45   [Warmoestraat 143, 1012 jb Amsterdam, Nederland]
# 46                                        [Nederland]
# 47        [Beursstraat, 1012 JV Amsterdam, Nederland]
# 48                                        [Nederland]
# 49  [Oude Hoogstraat 2 (Oudezijds Achterburgwal), ...
#
#                                        labeledLatLngs        lat       lng  \
# 0   [{'label': 'display', 'lat': 52.37204859355692...  52.372049  4.893601
# 1   [{'label': 'display', 'lat': 52.3750366665651,...  52.375037  4.891881
# 2   [{'label': 'display', 'lat': 52.36869570531105...  52.368696  4.889210
# 3   [{'label': 'display', 'lat': 52.36891, 'lng': ...  52.368910  4.889540
# 4   [{'label': 'display', 'lat': 52.373604, 'lng':...  52.373604  4.892299
# 5   [{'label': 'display', 'lat': 52.37158090831124...  52.371581  4.896721
# 6   [{'label': 'display', 'lat': 52.37356003581148...  52.373560  4.892024
# 7   [{'label': 'display', 'lat': 52.37213951322895...  52.372140  4.895055
# 8   [{'label': 'display', 'lat': 52.37075305612502...  52.370753  4.890934
# 9   [{'label': 'display', 'lat': 52.37089399126098...  52.370894  4.892891
# 10  [{'label': 'display', 'lat': 52.3711622685407,...  52.371162  4.891976
# 11  [{'label': 'display', 'lat': 52.37425802813496...  52.374258  4.892379
# 12  [{'label': 'display', 'lat': 52.371007, 'lng':...  52.371007  4.892909
# 13  [{'label': 'display', 'lat': 52.37155934759535...  52.371559  4.892825
# 14  [{'label': 'display', 'lat': 52.37012596827233...  52.370126  4.896367
# 15  [{'label': 'display', 'lat': 52.37523, 'lng': ...  52.375230  4.892498
# 16  [{'label': 'display', 'lat': 52.374564, 'lng':...  52.374564  4.890275
# 17  [{'label': 'display', 'lat': 52.37385, 'lng': ...  52.373850  4.895579
# 18  [{'label': 'display', 'lat': 52.37672198703562...  52.376722  4.897759
# 19  [{'label': 'display', 'lat': 52.36748966094193...  52.367490  4.892283
# 20  [{'label': 'display', 'lat': 52.376450638151, ...  52.376451  4.898229
# 21  [{'label': 'display', 'lat': 52.37043241903433...  52.370432  4.892001
# 22  [{'label': 'display', 'lat': 52.37316, 'lng': ...  52.373160  4.897785
# 23  [{'label': 'display', 'lat': 52.37301138619664...  52.373011  4.898269
# 24  [{'label': 'display', 'lat': 52.37035742160921...  52.370357  4.895811
# 25  [{'label': 'display', 'lat': 52.37487128457130...  52.374871  4.899034
# 26  [{'label': 'display', 'lat': 52.372208, 'lng':...  52.372208  4.886837
# 27  [{'label': 'display', 'lat': 52.37410627193225...  52.374106  4.897580
# 28  [{'label': 'display', 'lat': 52.37346758278578...  52.373468  4.898547
# 29  [{'label': 'display', 'lat': 52.37586964153297...  52.375870  4.898842
# 30  [{'label': 'display', 'lat': 52.373161, 'lng':...  52.373161  4.898917
# 31  [{'label': 'display', 'lat': 52.373514, 'lng':...  52.373514  4.898992
# 32  [{'label': 'display', 'lat': 52.37718, 'lng': ...  52.377180  4.895555
# 33  [{'label': 'display', 'lat': 52.377453, 'lng':...  52.377453  4.895840
# 34  [{'label': 'display', 'lat': 52.377174, 'lng':...  52.377174  4.889051
# 35  [{'label': 'display', 'lat': 52.378542, 'lng':...  52.378542  4.894101
# 36  [{'label': 'display', 'lat': 52.37320599395302...  52.373206  4.892846
# 37  [{'label': 'display', 'lat': 52.366761, 'lng':...  52.366761  4.894277
# 38  [{'label': 'display', 'lat': 52.37404292238903...  52.374043  4.898427
# 39  [{'label': 'display', 'lat': 52.37448598409153...  52.374486  4.895623
# 40  [{'label': 'display', 'lat': 52.373166, 'lng':...  52.373166  4.890660
# 41  [{'label': 'display', 'lat': 52.37442714366576...  52.374427  4.894726
# 42  [{'label': 'display', 'lat': 52.37319437712934...  52.373194  4.895740
# 43  [{'label': 'display', 'lat': 52.37558, 'lng': ...  52.375580  4.891759
# 44  [{'label': 'display', 'lat': 52.37387491685682...  52.373875  4.896812
# 45  [{'label': 'display', 'lat': 52.37375792493928...  52.373758  4.895666
# 46  [{'label': 'display', 'lat': 52.371654, 'lng':...  52.371654  4.895366
# 47  [{'label': 'display', 'lat': 52.374513, 'lng':...  52.374513  4.896014
# 48  [{'label': 'display', 'lat': 52.37429784385448...  52.374298  4.897328
# 49  [{'label': 'display', 'lat': 52.37152247815216...  52.371522  4.896843
#
#          neighborhood postalCode          state                        id
# 0                 NaN        NaN  Noord-Holland  5257fe4b11d27692834290b9
# 1                 NaN    1012 SH  Noord-Holland  4e2010e418a88345f03c3d3b
# 2                 NaN    1012 XA  Noord-Holland  4a2705cff964a520f5881fe3
# 3   Stadsdeel Centrum    1012 XA  Noord-Holland  5c681cc41acf11002c7aa0d7
# 4   Stadsdeel Centrum    1012 NP  Noord-Holland  5bdec64f8fb09e002cbbf24f
# 5                 NaN    1012 ED  Noord-Holland  4b165fe4f964a52085b823e3
# 6                 NaN    1012 LW  Noord-Holland  4a27db80f964a5202a941fe3
# 7                 NaN    1011 GA  Noord-Holland  4be166928d2b9521736390e4
# 8                 NaN        NaN            NaN  580b7d8938fa9e6be00d4705
# 9                 NaN    1012 KL  Noord-Holland  59523855f2905e33f2d2ad1e
# 10                NaN        NaN            NaN  4e87593f722e69455290a538
# 11                NaN        NaN  Noord-Holland  4e693e6788775d11dac3aed7
# 12                NaN    1012 KK  Noord-Holland  5c83d8ff2619ee002c5a30d1
# 13                NaN    1012 NX  Noord-Holland  5572e438498ee891ba700202
# 14                NaN    1012 CL  Noord-Holland  4c3ae49862f1c9284da28e53
# 15                NaN        NaN            NaN  57249ca3498e33891f94f08f
# 16                NaN    1012 VA  Noord-Holland  5d36c9733049270008c491d9
# 17                NaN        NaN            NaN  56c892c3498edfacfe9b3728
# 18                NaN        NaN  Noord-Holland  4fb8f019e4b042b08ec6f813
# 19                NaN        NaN  Noord-Holland  4c88a98c944e224b19f61d85
# 20                NaN        NaN  Noord-Holland  50125153582fbdd213201f30
# 21                NaN        NaN            NaN  566578b1498eb0210e65e96c
# 22                NaN        NaN            NaN  54de2f4b498edd530581d5f1
# 23                NaN        NaN            NaN  54de2ec0498ec09a2dccd2ef
# 24                NaN        NaN  Noord-Holland  4c9b9c62a004a1cde28c526e
# 25                NaN        NaN  Noord-Holland  4fb10b8fe4b0fa27b93c53c8
# 26                NaN        NaN            NaN  569265fc498ee19055e499af
# 27                NaN    1012 HA  Noord-Holland  4a2705cbf964a520e2881fe3
# 28                NaN        NaN            NaN  55d0df97498e3e0b3bbf1c3a
# 29                NaN    1012 JD  Noord-Holland  4a270000f964a520d3811fe3
# 30                NaN    1012 DB  Noord-Holland  57755643498e28300e65b45f
# 31                NaN    1012 DR  Noord-Holland  5d56ace3ae6b7300072983ba
# 32                NaN    1012 RC  Noord-Holland  5c4056985f68b9002cde761f
# 33  Stadsdeel Centrum     1012RC  Noord-Holland  593bd5ed75a6ea7d8a1a0dfe
# 34                NaN        NaN  Noord-Holland  5c9a1bcf234724002c3e70cc
# 35                NaN    1012 VC  Noord-Holland  592aa18bdb1d811307510111
# 36                NaN        NaN            NaN  56f1728e498e435173951928
# 37                NaN        NaN  Noord-Holland  577e39b6498e02cf5f422daa
# 38                NaN    1012 GX  Noord-Holland  51d98583498e78da6626be60
# 39                NaN    1012 JV  Noord-Holland  51c5cc0a498e570ebbb6a807
# 40                NaN        NaN  Noord-Holland  5819d850e13e1761538921e0
# 41                NaN        NaN  Noord-Holland  4af2d343f964a520a0e821e3
# 42                NaN        NaN  Noord-Holland  4fcf8457e4b0fea364d89713
# 43                NaN    1012 ST  Noord-Holland  5d4edf5048faba0008726e1c
# 44                NaN    1074 NZ  Noord-Holland  5e7befae91d452000877324d
# 45                NaN    1012 jb  Noord-Holland  4ae58dcbf964a520e3a021e3
# 46                NaN        NaN            NaN  521f7ba811d20f46d7445105
# 47                NaN    1012 JV  Noord-Holland  5c30de5175dcb7002cd38b03
# 48                NaN        NaN            NaN  4eb28777b8f7fd711e4d0632
# 49                NaN    1012 CE  Noord-Holland  4b0ba9f7f964a520e83223e3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the City Hall

# add a red  marker to represent the City Hall
folium.Circle(
    [latitude, longitude],
    radius=20,
    color='red',
    popup='City Hall',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Coffee Shops as blue markers
for lat, lng, label in zip(dfv_filtered.lat, dfv_filtered.lng, dfv_filtered.categories):
    folium.Circle(
        [lat, lng],
        radius=15,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
categoryId = "4bf58dd8d48988d163941735" #category id for parks
#search_query2 = "Park"
popular_url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, categoryId, radius, LIMIT)
popular_results = requests.get(popular_url).json()
# assign relevant information to the venues
popular = popular_results['response']['venues']
# transform to a dataframe
dfvp = json_normalize(popular)
dfvp.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id  location.address location.cc location.city  \
# 0  5200281a2fc61d655eaa7fb3  Oudemanhuispoort          NL     Amsterdam
# 1  4fd34c2ce4b0d6a97cf2e414               NaN          NL           NaN
# 2  4e162a668877d38dc9039945               NaN          NL     Amsterdam
#
#   location.country  location.distance  \
# 0        Nederland                493
# 1        Nederland                492
# 2        Nederland                622
#
#                           location.formattedAddress  \
# 0  [Oudemanhuispoort, 1012 CN Amsterdam, Nederland]
# 1                                       [Nederland]
# 2                            [Amsterdam, Nederland]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 52.36932732952832...     52.369327
# 1  [{'label': 'display', 'lat': 52.37746959744711...     52.377470
# 2  [{'label': 'display', 'lat': 52.36769, 'lng': ...     52.367690
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0      4.895917             De Wallen             1012 CN  Noord-Holland
# 1      4.894680                   NaN                 NaN            NaN
# 2      4.893580                   NaN                 NaN  Noord-Holland
#
#                        name    referralId
# 0          Oudemanhuispoort  v-1593601079
# 1     World Naked Bike Ride  v-1593601079
# 2  Bakje Tegenover L,europe  v-1593601079

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns2 = ['name', 'categories'] + [col for col in dfvp.columns if col.startswith('location.')] + ['id']
dfvp_filtered = dfvp.loc[:, filtered_columns2]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dfvp_filtered['categories'] = dfvp_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dfvp_filtered.columns = [column.split('.')[-1] for column in dfvp_filtered.columns]

dfvp_filtered
# Out:
#                        name categories           address  cc       city  \
# 0          Oudemanhuispoort       Park  Oudemanhuispoort  NL  Amsterdam
# 1     World Naked Bike Ride       Park               NaN  NL        NaN
# 2  Bakje Tegenover L,europe       Park               NaN  NL  Amsterdam
#
#      country  distance                                  formattedAddress  \
# 0  Nederland       493  [Oudemanhuispoort, 1012 CN Amsterdam, Nederland]
# 1  Nederland       492                                       [Nederland]
# 2  Nederland       622                            [Amsterdam, Nederland]
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 52.36932732952832...  52.369327  4.895917
# 1  [{'label': 'display', 'lat': 52.37746959744711...  52.377470  4.894680
# 2  [{'label': 'display', 'lat': 52.36769, 'lng': ...  52.367690  4.893580
#
#   neighborhood postalCode          state                        id
# 0    De Wallen    1012 CN  Noord-Holland  5200281a2fc61d655eaa7fb3
# 1          NaN        NaN            NaN  4fd34c2ce4b0d6a97cf2e414
# 2          NaN        NaN  Noord-Holland  4e162a668877d38dc9039945

# %%
# only keep the items that are category "Park"
dfvp_park = dfvp_filtered
dfvp_park = dfvp_park.loc[dfvp_park.categories == "Park"]
dfvp_park
# Out:
#                        name categories           address  cc       city  \
# 0          Oudemanhuispoort       Park  Oudemanhuispoort  NL  Amsterdam
# 1     World Naked Bike Ride       Park               NaN  NL        NaN
# 2  Bakje Tegenover L,europe       Park               NaN  NL  Amsterdam
#
#      country  distance                                  formattedAddress  \
# 0  Nederland       493  [Oudemanhuispoort, 1012 CN Amsterdam, Nederland]
# 1  Nederland       492                                       [Nederland]
# 2  Nederland       622                            [Amsterdam, Nederland]
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 52.36932732952832...  52.369327  4.895917
# 1  [{'label': 'display', 'lat': 52.37746959744711...  52.377470  4.894680
# 2  [{'label': 'display', 'lat': 52.36769, 'lng': ...  52.367690  4.893580
#
#   neighborhood postalCode          state                        id
# 0    De Wallen    1012 CN  Noord-Holland  5200281a2fc61d655eaa7fb3
# 1          NaN        NaN            NaN  4fd34c2ce4b0d6a97cf2e414
# 2          NaN        NaN  Noord-Holland  4e162a668877d38dc9039945

# %%
parks_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the City Hall

# add a red  marker to represent the the center of Amsterdam
folium.Circle(
    [latitude, longitude],
    radius=20,
    color='red',
    popup='City Hall',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(parks_map)

# add the Parks as green markers
for lat, lng, label in zip(dfvp_park.lat, dfvp_park.lng, dfvp_park.categories):
    folium.Circle(
        [lat, lng],
        radius=50,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(parks_map)

# display map
parks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
combined_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the City Hall

# add a red  marker to represent the center of Amsterdam
folium.Circle(
    [latitude, longitude],
    radius=20,
    color='red',
    popup='City Hall',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(combined_map)

# add the Parks as green markers
for lat, lng, label in zip(dfvp_park.lat, dfvp_park.lng, dfvp_park.categories):
    folium.Circle(
        [lat, lng],
        radius=50,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(combined_map)

# add the Coffee Shops as blue markers
for lat, lng, label in zip(dfv_filtered.lat, dfv_filtered.lng, dfv_filtered.categories):
    folium.Circle(
        [lat, lng],
        radius=15,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(combined_map)
    
# display map
combined_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dfvp_park["name"].count()
# Out:
# 3

# %%
dfv["name"].count()
# Out:
# 50

# %%
dist = dfvp_park[["distance","name"]]
dist2 = dfv_filtered[["distance","name"]]

# %%
dist
# Out:
#    distance                      name
# 0       493          Oudemanhuispoort
# 1       492     World Naked Bike Ride
# 2       622  Bakje Tegenover L,europe

# %%
dist2
# Out:
#     distance                                      name
# 0        152                       Lois Coffee & Jeans
# 1        204     Hostel Utopia/Coffee Shop (Amsterdam)
# 2        553                            Coffee Company
# 3        523                            Harar Coffee 2
# 4         42                              Naked Coffee
# 5        340                             Coffeecompany
# 6         48                        Coffee Club Damrak
# 7        211                           Coffeeshop Solo
# 8        297                            Coffee & Cakes
# 9        262                          Coffee bread bar
# 10       234  Coffee Shop Cafe Utrecht Utrech Panorama
# 11       113                      Blowerij Coffee Shop
# 12       250                      lexi’s Coffee&Bakery
# 13       188             Lot Sixty One Coffee Roasters
# 14       434                        Coffeeshop Rusland
# 15       221                          Canal Coffee Co.
# 16       211                        Sativa Coffee Shop
# 17       218                   original primium coffee
# 18       526                        Coffee@last Damrak
# 19       640                Coffee Company Kalvertoren
# 20       527                             Coffee @ last
# 21       314                   Pancakes Tosti's Coffee
# 22       358                          Louis Bed&Coffee
# 23       391                          Louis Bed&Coffee
# 24       391                      Cannabis Coffee Shop
# 25       478                       Highway Coffeeshoop
# 26       402                              Urban coffee
# 27       357                    Old Church Coffee Shop
# 28       410         Green Place Coffee Shop Amsterdam
# 29       519                       Hunter's Coffeeshop
# 30       435                    Dutchies Coffee & Shop
# 31       441                           District Coffee
# 32       484             Lot Sixty One Coffee Roasters
# 33       520           Miss Louisa Coffee And Beignets
# 34       496                              Bocca Coffee
# 35       599                              Tasty Coffee
# 36        22          prix d'amis coffeeshop amsterdam
# 37       731                     Tasty Donuts & Coffee
# 38       411                       De Koffieschenkerij
# 39       252                                Cut Throat
# 40       126                                coffeechop
# 41       199                                   coffeez
# 42       219                             CoffeeCompany
# 43       265                    Coffeeshop Mediteranne
# 44       300                 Coffeeshop weed deliveren
# 45       221                                 Greendayz
# 46       262                      Coffeeshop City Hall
# 47       276                        Coffeeshop Babylon
# 48       347                   Coffeeshop The Basement
# 49       351                         Coffeeshop Extase

# %%
dist2.plot(kind='bar', figsize=(10, 6))
plt.xlabel('name')
plt.ylabel('distance')
plt.title('distance from City Hall for coffee shops')
plt.show()
